# %%
#Import all relevant libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import zscore
import plotly.express as px
 
## This statement allows the visuals to render within your Jupyter Notebook.
# %matplotlib inline

# %% [markdown]
# ## reading the data

# %%
df = pd.read_csv("Data/product_details.csv")

# %% [markdown]
# ## Viewing the dataframe

# %%
df.head()
# Out:
#                        Product Title Product Price  Warranty Period (Months)  \
# 0          Huawei MateBook 14 Laptop         4,299                      24.0
# 1     Apple MacBook Air 15 M3 Laptop         5,999                      24.0
# 2     Apple MacBook Air 15 M3 Laptop         5,999                      24.0
# 3                        Asus Laptop         3,799                      24.0
# 4  Microsoft Surface Laptop 7 Laptop         9,699                      24.0
#
#   Accesorises warranty  Warranted by       SKU Manufacturer Number  \
# 0            12 Months  Manufacturer  638525.0            53014ASK
# 1            12 Months  Manufacturer  646475.0            MC9D4ABA
# 2            12 Months  Manufacturer  632673.0            MRYR3ABA
# 3            12 Months  Manufacturer  642879.0       UM3406OLEDR7W
# 4       Not Applicable         JARIR  639206.0            ZHI00014
#
#                processor type  NPU (Neural Processing Unit)  \
# ...

# %%
df.shape
# Out:
# (205, 40)

# %%
df.describe().T
# Out:
#                           count           mean           std        min  \
# Warranty Period (Months)  198.0      23.287879      5.002837       3.00
# SKU                       198.0  630823.853535  16440.520343  558437.00
# generation/release        198.0    2023.404040      0.848040    2020.00
# Shipping Weight (kg)        3.0       2.430000      0.000000       2.43
# Renewed Remarks            10.0  608250.300000  25682.055050  558440.00
#
#                                 25%        50%        75%        max
# Warranty Period (Months)      24.00      24.00      24.00      60.00
# SKU                       626247.25  632677.50  643688.50  646502.00
# generation/release          2023.00    2024.00    2024.00    2024.00
# Shipping Weight (kg)           2.43       2.43       2.43       2.43
# Renewed Remarks           589224.50  617354.00  626873.50  635355.00

# %%
df.describe(include='object').T
# Out:
#                               count unique  \
# Product Title                   205     84
# Product Price                   205     92
# Accesorises warranty            198      3
# Warranted by                    198      3
# Manufacturer Number             198    198
# processor type                  198     58
# NPU (Neural Processing Unit)    113      6
# AI (Artificial Intelligence)    112      1
# display type                    198     43
# graphics card                   198     23
# display size                    198     12
# operating system                198     10
# product type                    198      2
# model/chipset number             83     65
# model series                    198     25
# color                           197     43
# operating system architecture    98      1
# processor speed                 104     44
# capacity                        198     19
# RAM                             198      7
# connectivity technology         198      9
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 40 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Product Title                  205 non-null    object
#  1   Product Price                  205 non-null    object
#  2   Warranty Period (Months)       198 non-null    float64
#  3   Accesorises warranty           198 non-null    object
#  4   Warranted by                   198 non-null    object
#  5   SKU                            198 non-null    float64
#  6   Manufacturer Number            198 non-null    object
#  7   processor type                 198 non-null    object
#  8   NPU (Neural Processing Unit)   113 non-null    object
#  9   AI (Artificial Intelligence)   112 non-null    object
#  10  display type                   198 non-null    object
#  11  graphics card                  198 non-null    object
# ...

# %% [markdown]
# # cleaning

# %% [markdown]
# ## nulls

# %%
#columns with nulls i know the answer too :)
columns_with_issues = ['fingerprint', 'card reader', 'touch display', 'AI (Artificial Intelligence)']

# changed these columns type to boolean 
df[columns_with_issues] = df[columns_with_issues].apply(lambda x: x != 'no')

# Check if the operation was successful
df[columns_with_issues]
# Out:
#      fingerprint  card reader  touch display  AI (Artificial Intelligence)
# 0           True         True           True                          True
# 1           True         True           True                          True
# 2           True         True           True                          True
# 3           True         True           True                          True
# 4           True         True           True                          True
# ..           ...          ...            ...                           ...
# 200         True         True           True                          True
# 201         True         True           True                          True
# 202         True         True           True                          True
# 203         True         True           True                          True
# 204         True         True           True                          True
#
# [205 rows x 4 columns]

# %%
df.dtypes
# Out:
# Product Title                     object
# Product Price                     object
# Warranty Period (Months)         float64
# Accesorises warranty              object
# Warranted by                      object
# SKU                              float64
# Manufacturer Number               object
# processor type                    object
# NPU (Neural Processing Unit)      object
# AI (Artificial Intelligence)        bool
# display type                      object
# graphics card                     object
# display size                      object
# operating system                  object
# product type                      object
# model/chipset number              object
# model series                      object
# generation/release               float64
# color                             object
# operating system architecture     object
# processor speed                   object
# capacity                          object
# RAM                               object
# ...

# %% [markdown]
# ## duplicates

# %%
df.duplicated().sum()
# Out:
# 5
